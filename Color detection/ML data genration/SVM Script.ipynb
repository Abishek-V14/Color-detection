# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('data.csv',index_col = 'Unnamed: 0')
print(df)
# Out:
#        R    G    B       C
# 0     41  131  109     red
# 1     50  137  101     red
# 2     46  130   99     red
# 3     38  139  113     red
# 4     37  135  104     red
# ...   ..  ...  ...     ...
# 1595  49  130  104  orange
# 1596  37  144  124  orange
# 1597  33   99  125  orange
# 1598  32  129  129  orange
# 1599  37  115  126  orange
#
# [1600 rows x 4 columns]

# %%
x = df.drop('C',axis = 1)
y = df['C']
print(y)
# Out:
# 0          red
# 1          red
# 2          red
# 3          red
# 4          red
#          ...
# 1595    orange
# 1596    orange
# 1597    orange
# 1598    orange
# 1599    orange
# Name: C, Length: 1600, dtype: object

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
ss = StandardScaler()
x = ss.fit_transform(x)
print(x)
# Out:
# [[-0.95472106  0.5184788   0.57833953]
#  [-0.79719258  0.63665341  0.38198022]
#  [-0.86720524  0.49878303  0.33289039]
#  ...
#  [-1.09474638 -0.1117858   0.97105815]
#  [-1.11224955  0.47908726  1.06923781]
#  [-1.02473372  0.2033465   0.99560307]]

# %%
le = LabelEncoder()
y = le.fit_transform(y)
print(y)
# Out:
# [12 12 12 ... 10 10 10]

# %%
clf = SVC()
clf.fit(x_train,y_train)
pred = clf.predict(x_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#        black       1.00      0.91      0.95        11
#         blue       0.86      1.00      0.92         6
#        brown       0.82      1.00      0.90         9
#    dark_blue       1.00      0.92      0.96        13
#   dark_green       1.00      1.00      1.00         8
#        green       1.00      1.00      1.00        10
#         grey       0.93      1.00      0.97        14
#   light_blue       1.00      1.00      1.00        12
#  light_green       1.00      1.00      1.00         7
#       maroon       1.00      1.00      1.00         5
#       orange       1.00      0.86      0.92         7
#         pink       1.00      1.00      1.00        11
#          red       0.93      1.00      0.96        13
#       violet       1.00      1.00      1.00        11
#        white       1.00      1.00      1.00        13
#       yellow       1.00      0.80      0.89        10
#
#     accuracy                           0.97       160
#    macro avg       0.97      0.97      0.97       160
# weighted avg       0.97      0.97      0.97       160

# %%
print(clf.score(x_test,y_test))
# Out:
# 0.96875

# %%
import pickle

# %%
with open('ml_model.pkl', 'wb') as file:
    pickle.dump(clf, file)
